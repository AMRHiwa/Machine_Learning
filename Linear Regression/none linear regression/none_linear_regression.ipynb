# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pylab as pl

# %%
df = pd.read_csv('china_gdp.csv')
df.head()
# Out:
#    Year         Value
# 0  1960  5.918412e+10
# 1  1961  4.955705e+10
# 2  1962  4.668518e+10
# 3  1963  5.009730e+10
# 4  1964  5.906225e+10

# %%
x_data, y_data = (df.Year, df.Value)

plt.scatter(x_data, y_data)
plt.xlabel('Year')
plt.ylabel('GDP')
plt.show()

# %%
x = np.arange(-5, 5, 0.1)
y = 1 / (1 - np.exp(-x))

plt.plot(x, y)
plt.show()

# %%
def sigmoid(x, beta_1, beta_2):
    y = 1 / (1 - np.exp(-beta_1 * (x - beta_2)))
    return y

# %% [markdown]
# normalized data

# %%
x_data_normal = x_data / max(x_data)
y_data_normal = y_data / max(y_data)

# %%
plt.scatter(x_data_normal, y_data_normal)

# %%
from scipy.optimize import curve_fit
popt, pcov = curve_fit(sigmoid, x_data_normal, y_data_normal)
print(f'beta 1 is : {popt[0]}\nbeta 2 is :{popt[1]}')
# Out:
# beta 1 is : 1.0
# beta 2 is :1.0

# %%
beta_1 = 1
beta_2 = 1
y = sigmoid(x_data_normal, beta_1, beta_2)
# print(np.abs(y))
plt.scatter(x_data_normal, y_data_normal)
plt.plot(x_data_normal, np.abs(y))
