# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('train_Titanic.csv')

# %%
df.info
# Out:
# <bound method DataFrame.info of      PassengerId  Pclass                                               Name  \
# 0              1       3                            Braund, Mr. Owen Harris
# 1              2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3       3                             Heikkinen, Miss. Laina
# 3              4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5       3                           Allen, Mr. William Henry
# ..           ...     ...                                                ...
# 886          887       2                              Montvila, Rev. Juozas
# 887          888       1                       Graham, Miss. Margaret Edith
# 888          889       3           Johnston, Miss. Catherine Helen "Carrie"
# 889          890       1                              Behr, Mr. Karl Howell
# 890          891       3                                Dooley, Mr. Patrick
#
# ...

# %%
df
# Out:
#      PassengerId  Pclass                                               Name  \
# 0              1       3                            Braund, Mr. Owen Harris
# 1              2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3       3                             Heikkinen, Miss. Laina
# 3              4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5       3                           Allen, Mr. William Henry
# ..           ...     ...                                                ...
# 886          887       2                              Montvila, Rev. Juozas
# 887          888       1                       Graham, Miss. Margaret Edith
# 888          889       3           Johnston, Miss. Catherine Helen "Carrie"
# 889          890       1                              Behr, Mr. Karl Howell
# 890          891       3                                Dooley, Mr. Patrick
#
# ...

# %%
df.shape
# Out:
# (891, 12)

# %%
df.head(6)
# Out:
#    PassengerId  Pclass                                               Name  \
# 0            1       3                            Braund, Mr. Owen Harris
# 1            2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2            3       3                             Heikkinen, Miss. Laina
# 3            4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4            5       3                           Allen, Mr. William Henry
# 5            6       3                                   Moran, Mr. James
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S
# ...

# %%
def f(name):
    if '.' in name:
        return name.split(',')[1].split('.')[0].strip()
    else:
        return 'Unknow'

# %%
def g(t):
    if t == 'Mr':
        return 1
    elif t == 'Master':
        return 3
    elif t in ['Ms', 'Mlle', 'Miss']:
        return 4
    elif t in ['Mrs', 'Mme']:
        return 5
    else:
        return 2

# %%
df['title'] = df['Name'].apply(f).apply(g)
df.head(10)
# Out:
#    PassengerId  Pclass                                               Name  \
# 0            1       3                            Braund, Mr. Owen Harris
# 1            2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2            3       3                             Heikkinen, Miss. Laina
# 3            4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4            5       3                           Allen, Mr. William Henry
# 5            6       3                                   Moran, Mr. James
# 6            7       1                            McCarthy, Mr. Timothy J
# 7            8       3                     Palsson, Master. Gosta Leonard
# 8            9       3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9           10       2                Nasser, Mrs. Nicholas (Adele Achem)
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# ...

# %%
t = pd.crosstab(df['title'], df['Survived'])
t
# Out:
# Survived    0    1
# title
# 1         436   81
# 2          15    8
# 3          17   23
# 4          55  130
# 5          26  100

# %%
t_pict = t.div(t.sum(1).astype(float), axis=0)
t_pict
# Out:
# Survived         0         1
# title
# 1         0.843327  0.156673
# 2         0.652174  0.347826
# 3         0.425000  0.575000
# 4         0.297297  0.702703
# 5         0.206349  0.793651

# %%
t_pict.plot(kind='bar', stacked=True, title='Survival Rate by title')
plt.xlabel('title')
plt.ylabel('Survival Rate')
# Out:
# Text(0, 0.5, 'Survival Rate')

# %%
df.drop(['PassengerId', 'Name', 'Ticket'], axis=1)
df
# Out:
#      PassengerId  Pclass                                               Name  \
# 0              1       3                            Braund, Mr. Owen Harris
# 1              2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3       3                             Heikkinen, Miss. Laina
# 3              4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5       3                           Allen, Mr. William Henry
# ..           ...     ...                                                ...
# 886          887       2                              Montvila, Rev. Juozas
# 887          888       1                       Graham, Miss. Margaret Edith
# 888          889       3           Johnston, Miss. Catherine Helen "Carrie"
# 889          890       1                              Behr, Mr. Karl Howell
# 890          891       3                                Dooley, Mr. Patrick
#
# ...

# %%
edt = pd.get_dummies(df['Embarked'])
edt
# Out:
#      C  Q  S
# 0    0  0  1
# 1    1  0  0
# 2    0  0  1
# 3    0  0  1
# 4    0  0  1
# ..  .. .. ..
# 886  0  0  1
# 887  0  0  1
# 888  0  0  1
# 889  1  0  0
# 890  0  1  0
#
# [891 rows x 3 columns]

# %%
edt.drop(['S'], axis=1, inplace=True)
edt
# Out:
#      C  Q
# 0    0  0
# 1    1  0
# 2    0  0
# 3    0  0
# 4    0  0
# ..  .. ..
# 886  0  0
# 887  0  0
# 888  0  0
# 889  1  0
# 890  0  1
#
# [891 rows x 2 columns]

# %%
df = df.join(edt)
df
# Out:
#      PassengerId  Pclass                                               Name  \
# 0              1       3                            Braund, Mr. Owen Harris
# 1              2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3       3                             Heikkinen, Miss. Laina
# 3              4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5       3                           Allen, Mr. William Henry
# ..           ...     ...                                                ...
# 886          887       2                              Montvila, Rev. Juozas
# 887          888       1                       Graham, Miss. Margaret Edith
# 888          889       3           Johnston, Miss. Catherine Helen "Carrie"
# 889          890       1                              Behr, Mr. Karl Howell
# 890          891       3                                Dooley, Mr. Patrick
#
# ...

# %%
df.drop(['Embarked'], axis=1, inplace=True)
df.head(10)
# Out:
#    PassengerId  Pclass                                               Name  \
# 0            1       3                            Braund, Mr. Owen Harris
# 1            2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2            3       3                             Heikkinen, Miss. Laina
# 3            4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4            5       3                           Allen, Mr. William Henry
# 5            6       3                                   Moran, Mr. James
# 6            7       1                            McCarthy, Mr. Timothy J
# 7            8       3                     Palsson, Master. Gosta Leonard
# 8            9       3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9           10       2                Nasser, Mrs. Nicholas (Adele Achem)
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin  Survived  \
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN         0
# ...

# %% [markdown]
# # Example GroupBy

# %%
df = pd.DataFrame({'Bird': list('AABBB'), 'Speed': [380, 370, 24, 26, np.nan]})
df
# Out:
#   Bird  Speed
# 0    A  380.0
# 1    A  370.0
# 2    B   24.0
# 3    B   26.0
# 4    B    NaN

# %%
df.groupby('Bird').mean()
# Out:
#       Speed
# Bird
# A     375.0
# B      25.0

# %%
df['Speed'] = df.groupby(['Bird'])['Speed'].transform(lambda x : x.fillna(x.mean()))

df
# Out:
#   Bird  Speed
# 0    A  380.0
# 1    A  370.0
# 2    B   24.0
# 3    B   26.0
# 4    B   25.0
